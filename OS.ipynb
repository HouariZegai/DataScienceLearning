# %%
import os # import operating system lib

# %%
current_dir = os.getcwd()
print(current_dir)
# Out:
# C:\Users\houar\Documents\DataScienceCourse

# %%
os.mkdir("newFolder") # create new folder

# %%
os.rename('newFolder', 'newFolder2') # rename folder

# %%
os.rmdir('newFolder2') # remove folder
