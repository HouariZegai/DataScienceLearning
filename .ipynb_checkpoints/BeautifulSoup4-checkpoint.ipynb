# %% [markdown]
# # Beautiful Soup
# ### for get data from any thing (website, ...)

# %%
# import libraries
import bs4 as bs
import urllib.request
from urllib.request import urlopen

url = urlopen('http://stackoverflow.com').read()

# %%
soup = bs.BeautifulSoup(url, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="html__responsive">
# <head>
# <title>Stack Overflow - Where Developers Learn, Share, &amp; Build Careers</title>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/img/favicon.ico?v=4f32ecc8f43d" rel="shortcut icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon image_src"/>
# <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
# <meta content="Stack Overflow is the largest, most trusted online community for developers to learn, share​ ​their programming ​knowledge, and build their careers." name="description"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="website" property="og:type"/>
# <meta content="https://stackoverflow.com/" property="og:url"/>
# <meta content="Stack Overflow" property="og:site_name"/>
# <meta content="https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon@2.png?v=73d79a89bded" itemprop="image primaryImageOfPage" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="stackoverflow.com" name="twitter:domain"/>
# <meta content="Stack Overflow - Where Developers Learn, Share, &amp; Build Careers" itemprop="name" name="twitter:title" property="og:title"/>
# <meta content="Stack Overflow | The World’s Largest Online Community for Developers" itemprop="description" name="twitter:description" property="og:description"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# <script src="https://cdn.sstatic.net/Js/stub.en.js?v=780f7bfc2feb"></script>
# <link href="https://cdn.sstatic.net/Shared/stacks.css?v=0dba668d3e12" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=e33cda77cf6b" rel="stylesheet" type="text/css"/>
# <link href="/feeds" rel="alternate" title="Feed of recent questions" type="application/atom+xml"/>
# <script>
#         StackExchange.init({"locale":"en","serverTime":1550829587,"routeName":"Home/Index","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack Overflow","description":"Q&A for professional and enthusiast programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"childUrl":"https://meta.stackoverflow.com","enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"f3b4b49eb5a6c1a024886274345908a101122e2731fb4b301e3b842a8b89b270","tid":"30990948-054a-43e3-473d-6fd89cc05437","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true,"ab":{"inline_signup_hero":{"v":"d","g":2}}},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/svg-icons","svgIconHash":"840d669a9425"}, {"site":{"allowImageUploads":true,"enableUserHovercards":true,"styleCode":true,"enableImgurHttps":true,"forceHttpsImages":true},"userMessaging":{},"comments":{},"userProfile":{"openGraphAPIKey":"58740831ad23540e00c58987"},"tags":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true},"flags":{"allowRetractingFlags":true},"snippets":{"snippetsEnabled":true,"renderDomain":"stacksnippets.net"},"paths":{},"markdown":{"asteriskIntraWordEmphasis":true},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"slack":{"sidebarAdDismissCookie":"slack-sidebar-ad"}});
#         StackExchange.using.setCacheBreakers({"js/prettify-full.en.js":"bae0a7a08996","js/moderator.en.js":"8a01037f6888","js/full-anon.en.js":"0aae59023270","js/full.en.js":"6a199cca007f","js/wmd.en.js":"26a9b8b243e1","js/mobile.en.js":"fc572a0c9026","js/help.en.js":"769f1d4dbaab","js/tageditor.en.js":"da9334be6f55","js/tageditornew.en.js":"8a56ecfe0d6f","js/inline-tag-editing.en.js":"8bea6d7daa14","js/revisions.en.js":"d059a98114ef","js/review.en.js":"3c194616fd66","js/tagsuggestions.en.js":"1b1fef557065","js/post-validation.en.js":"2a43250a6641","js/explore-qlist.en.js":"5c7424c271ef","js/events.en.js":"089e7e8c9abc","js/keyboard-shortcuts.en.js":"d186e7ec56df","js/external-editor.en.js":"7d20a0b245c2","js/adops.en.js":"22a9bd59b1e9","js/begin-edit-event.en.js":"7415f5dee62d","js/stacks-polyfills.en.js":"917f0bda8241","js/external-editor.en.js":"7d20a0b245c2","js/snippet-javascript.en.js":"6d2231c425d1","js/snippet-javascript-codemirror.en.js":"eadcfea3bf9c"});
#         StackExchange.using("gps", function() {
#              StackExchange.gps.init(true);
#         });
#     </script>
# <noscript id="noscript-css"><style>body,.top-bar{margin-top:1.9em}</style></noscript>
# </head>
# <body class="home-page unified-theme">
# <div id="notify-container"></div>
# <div id="custom-header"></div>
# <header class="top-bar js-top-bar top-bar__network _fixed">
# <div class="-container">
# <div class="-main">
# <a class="left-sidebar-toggle p0 ai-center jc-center js-left-sidebar-toggle" href="#"><span class="ps-relative"></span></a>
# <a class="-logo js-gps-track" data-gps-track="top_nav.click({is_current:true, location:1, destination:8})" href="https://stackoverflow.com">
# <span class="-img _glyph">Stack Overflow</span>
# </a>
# </div>
# <form action="/search" autocomplete="off" class="searchbar js-searchbar " id="search" method="get" role="search">
# <div class="ps-relative">
# <input autocomplete="off" class="s-input js-search-field " maxlength="240" name="q" placeholder="Search…" type="text" value=""/>
# <button aria-label="Search…" class="s-btn s-btn__primary s-btn__icon btn-topbar-primary js-search-submit" type="submit"><svg aria-hidden="true" class="svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18"><path d="M12.86 11.32L18 16.5 16.5 18l-5.18-5.14v-.35a7 7 0 1 1 1.19-1.19h.35zM7 12A5 5 0 1 0 7 2a5 5 0 0 0 0 10z"></path></svg></button>
# </div>
# </form>
# <ol class="-secondary js-secondary-topbar-links drop-icons-responsively">
# <li class="-item searchbar-trigger js-searchbar-trigger"><a class="-link" href="#"><svg aria-hidden="true" class="svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18"><path d="M12.86 11.32L18 16.5 16.5 18l-5.18-5.14v-.35a7 7 0 1 1 1.19-1.19h.35zM7 12A5 5 0 1 0 7 2a5 5 0 0 0 0 10z"></path></svg></a></li>
# <li class="-item">
# <a class="-link js-inbox-button" href="https://stackexchange.com/users/?tab=inbox" title="Recent inbox messages">
# <svg aria-hidden="true" class="svg-icon iconInbox" height="18" viewbox="0 0 20 18" width="20"><path d="M15.19 1H4.63c-.85 0-1.6.54-1.85 1.35L0 10.79V15c0 1.1.9 2 2 2h16a2 2 0 0 0 2-2v-4.21l-2.87-8.44A2 2 0 0 0 15.19 1zm-.28 10l-2 2h-6l-2-2H1.96L4.4 3.68A1 1 0 0 1 5.35 3h9.12a1 1 0 0 1 .95.68L17.86 11h-2.95z"></path></svg>
# <span class="indicator-badge js-unread-count _important" style="display: none;"></span>
# </a>
# </li>
# <li class="-item">
# <a class="-link js-achievements-button" data-unread-class="_highlighted-positive" href="https://stackexchange.com/users/?tab=reputation" title="Recent achievements: reputation, badges, and privileges earned">
# <svg aria-hidden="true" class="svg-icon iconAchievements" height="18" viewbox="0 0 18 18" width="18"><path d="M15 2V1H3v1H0v4c0 1.6 1.4 3 3 3v1c.4 1.5 3 2.6 5 3v2H5s-1 1.5-1 2h10c0-.4-1-2-1-2h-3v-2c2-.4 4.6-1.5 5-3V9c1.6-.2 3-1.4 3-3V2h-3zM3 7c-.5 0-1-.5-1-1V4h1v3zm8.4 2.5L9 8 6.6 9.4l1-2.7L5 5h3l1-2.7L10 5h2.8l-2.3 1.8 1 2.7h-.1zM16 6c0 .5-.5 1-1 1V4h1v2z"></path></svg>
# <span class="indicator-badge js-unread-count _positive" style="display: none;"></span>
# </a>
# </li>
# <li class="-item help-button-item" data-remove-order="1"><a class="-link js-help-button" href="#" title="Help Center and other resources">
# <svg aria-hidden="true" class="svg-icon iconHelp" height="18" viewbox="0 0 18 18" width="18"><path d="M9 1a8 8 0 1 0 0 16A8 8 0 0 0 9 1zm.81 12.13c-.02.71-.55 1.15-1.24 1.13-.66-.02-1.17-.49-1.15-1.2.02-.72.56-1.18 1.22-1.16.7.03 1.2.51 1.17 1.23zM11.77 8a5.8 5.8 0 0 1-1.02.91l-.53.37c-.26.2-.42.43-.5.69a4 4 0 0 0-.09.75c0 .05-.03.16-.18.16H7.88c-.16 0-.18-.1-.18-.15.03-.66.12-1.21.4-1.66a5.29 5.29 0 0 1 1.43-1.22c.16-.12.28-.25.38-.39a1.34 1.34 0 0 0 .02-1.71c-.24-.31-.51-.46-1.03-.46-.51 0-.8.26-1.02.6-.21.33-.18.73-.18 1.1H5.75c0-1.38.35-2.25 1.1-2.76.52-.35 1.17-.5 1.93-.5 1 0 1.79.18 2.49.71.64.5.98 1.18.98 2.12 0 .57-.2 1.05-.48 1.44z"></path></svg>
# </a></li>
# <li class="-item site-switcher-item">
# <a class="-link js-site-switcher-button js-gps-track" data-gps-track="site_switcher.show" href="https://stackexchange.com" title="A list of all 175 Stack Exchange sites">
# <svg aria-hidden="true" class="svg-icon iconStackExchange" height="18" viewbox="0 0 18 18" width="18"><path d="M1 13c0 1.1.9 2 2 2h8v3l3-3h1a2 2 0 0 0 2-2v-2H1v2zM15 1H3a2 2 0 0 0-2 2v2h16V3a2 2 0 0 0-2-2zM1 6h16v4H1V6z"></path></svg>
# </a>
# </li>
# <li class="-ctas">
# <a class="login-link s-btn btn-topbar-clear py8" href="https://stackoverflow.com/users/login?ssrc=head&amp;returnurl=https%3a%2f%2fstackoverflow.com%2f" rel="nofollow">Log In</a>
# <a class="login-link s-btn s-btn__primary py8 btn-topbar-primary" data-ga='["sign up","Sign Up Navigation","Header",null,null]' href="https://stackoverflow.com/users/signup?ssrc=head&amp;returnurl=%2fusers%2fstory%2fcurrent" rel="nofollow">Sign Up</a>
# </li>
# <li class="-dialog-container js-topbar-dialog-corral">
# <div class="topbar-dialog siteSwitcher-dialog dno">
# <div class="header">
# <h3><a href="https://stackoverflow.com">current community</a>
# </h3>
# </div>
# <div class="modal-content current-site-container">
# <ul class="current-site">
# <li class="grid">
# <div class="fl1">
# <a class="current-site-link site-link js-gps-track grid gs8 gsx" data-gps-track="site_switcher.click({ item_type:3 })" data-id="1" href="https://stackoverflow.com">
# <div class="favicon favicon-stackoverflow site-icon grid--cell" title="Stack Overflow"></div>
# <span class="grid--cell fl1">
#             Stack Overflow
#         </span>
# </a>
# </div>
# <div class="related-links">
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:14 })" href="https://stackoverflow.com/help">help</a>
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:6 })" href="https://chat.stackoverflow.com">chat</a>
# </div>
# </li>
# <li class="related-site grid">
# <div class="L-shaped-icon-container">
# <span class="L-shaped-icon"></span>
# </div>
# <a class="site-link js-gps-track grid gs8 gsx" data-gps-track="site.switch({ target_site:552, item_type:3 }),site_switcher.click({ item_type:4 })" data-id="552" href="https://meta.stackoverflow.com">
# <div class="favicon favicon-stackoverflowmeta site-icon grid--cell" title="Meta Stack Overflow"></div>
# <span class="grid--cell fl1">
#             Meta Stack Overflow
#         </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="header" id="your-communities-header">
# <h3>
# your communities            </h3>
# </div>
# <div class="modal-content" id="your-communities-section">
# <div class="call-to-login">
# <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:10 })" href="https://stackoverflow.com/users/signup?ssrc=site_switcher&amp;returnurl=%2fusers%2fstory%2fcurrent">Sign up</a> or <a class="login-link js-gps-track" data-gps-track="site_switcher.click({ item_type:11 })" href="https://stackoverflow.com/users/login?ssrc=site_switcher&amp;returnurl=https%3a%2f%2fstackoverflow.com%2f">log in</a> to customize your list.
#                 </div>
# </div>
# <div class="header">
# <h3><a href="https://stackexchange.com/sites">more stack exchange communities</a>
# </h3>
# <a class="fr" href="https://stackoverflow.blog">company blog</a>
# </div>
# <div class="modal-content">
# <div class="child-content"></div>
# </div>
# </div>
# <div class="topbar-dialog help-dialog js-help-dialog dno">
# <div class="modal-content">
# <ul>
# <li>
# <a class="js-gps-track" data-gps-track="help_popup.click({ item_type:1 })" href="/tour">
#                             Tour
#                             <span class="item-summary">
#                                 Start here for a quick overview of the site
#                             </span>
# </a>
# </li>
# <li>
# <a class="js-gps-track" data-gps-track="help_popup.click({ item_type:4 })" href="/help">
#                         Help Center
#                         <span class="item-summary">
#                             Detailed answers to any questions you might have
#                         </span>
# </a>
# </li>
# <li>
# <a class="js-gps-track" data-gps-track="help_popup.click({ item_type:2 })" href="https://meta.stackoverflow.com">
#                                 Meta
#                                 <span class="item-summary">
#                                     Discuss the workings and policies of this site
#                                 </span>
# </a>
# </li>
# <li>
# <a class="js-gps-track" data-gps-track="help_popup.click({ item_type:6 })" href="https://stackoverflow.com/company/about">
#                                 About Us
#                                 <span class="item-summary">
#                                     Learn more about Stack Overflow the company
#                                 </span>
# </a>
# </li>
# <li>
# <a class="js-gps-track" data-gps-track="help_popup.click({ item_type:7 })" href="https://www.stackoverflowbusiness.com/?ref=topbar_help">
#                                 Business
#                                 <span class="item-summary">
#                                     Learn more about hiring developers or posting ads with us
#                                 </span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="topbar-dialog leftnav-dialog js-leftnav-dialog dno">
# <div class="left-sidebar js-unpinned-left-sidebar" data-can-be="left-sidebar" data-is-here-when="sm"></div>
# </div>
# </li>
# </ol>
# </div>
# </header>
# <div aria-hidden="false" class="p16 bg-black-700 ff-sans fc-white ps-fixed b0 l0 r0 z-banner" id="js-gdpr-consent-banner" role="banner">
# <div aria-describedby="notice-message" class="wmx8 mx-auto grid jc-center" role="alertdialog">
# <div aria-label="notice-message" class="grid--cell mr12">
# <p class="mb0 lh-lg">
#                     By using our site, you acknowledge that you have read and understand our <a class="s-link s-link__inherit td-underline fc-white" href="https://stackoverflow.com/legal/cookie-policy" target="_blank">Cookie Policy</a>, <a class="s-link s-link__inherit td-underline fc-white" href="https://stackoverflow.com/legal/privacy-policy" target="_blank">Privacy Policy</a>, and our <a class="s-link s-link__inherit td-underline fc-white" href="https://stackoverflow.com/legal/terms-of-service/public" target="_blank">Terms of Service</a>.
#                 </p>
# </div>
# <a aria-label="notice-dismiss" class="grid--cell fc-white js-notice-close">
# <svg aria-hidden="true" class="svg-icon m0 iconClear" height="18" viewbox="0 0 18 18" width="18"><path d="M15 4.41L13.59 3 9 7.59 4.41 3 3 4.41 7.59 9 3 13.59 4.41 15 9 10.41 13.59 15 15 13.59 10.41 9z"></path></svg>
# </a>
# </div>
# </div>
# <script>
#         StackExchange.ready(function () { StackExchange.topbar.init({ observeSize: true }); });
#         StackExchange.scrollPadding.setPaddingTop(50, 10);     </script>
# <div class="container">
# <div class="left-sidebar js-pinned-left-sidebar" data-is-here-when="md lg" id="left-sidebar">
# <div class="left-sidebar--sticky-container js-sticky-leftnav">
# <nav role="navigation">
# <ol class="nav-links">
# <li> </li><li class=" youarehere">
# <a class="pl8 js-gps-track nav-links--link" data-gps-track="top_nav.click({is_current:true, location:1, destination:8})" href="/">
# Home        </a>
# </li>
# <li>
# <ol class="nav-links">
# <li class="fs-fine tt-uppercase ml8 mt16 mb4 fc-light">Public</li>
# <li>
# <a class="pl8 js-gps-track nav-links--link -link__with-icon" data-gps-track="top_nav.click({is_current:false, location:1, destination:1})" href="/questions" id="nav-questions">
# <svg aria-hidden="true" class="svg-icon iconGlobe" height="18" viewbox="0 0 18 18" width="18"><path d="M9 1a8 8 0 1 0 0 16A8 8 0 0 0 9 1zM8 15.32a6.4 6.4 0 0 1-5.23-7.75L7 11.68v.8c0 .88.12 1.32 1 1.32v1.52zm5.72-2c-.2-.66-1-1.32-1.72-1.32h-1v-2c0-.44-.56-1-1-1H6V7h1c.44 0 1-.56 1-1V5h2c.88 0 1.4-.72 1.4-1.6v-.33a6.4 6.4 0 0 1 2.32 10.24z"></path></svg> <span class="-link--channel-name">Stack Overflow</span>
# </a>
# </li>
# <li>
# <a class=" js-gps-track nav-links--link" data-gps-track="top_nav.click({is_current:false, location:1, destination:2})" href="/tags" id="nav-tags">
# Tags        </a>
# </li>
# <li>
# <a class=" js-gps-track nav-links--link" data-gps-track="top_nav.click({is_current:false, location:1, destination:3})" href="/users" id="nav-users">
# Users        </a>
# </li>
# <li>
# <a class=" js-gps-track nav-links--link" data-gps-track="top_nav.click({is_current:false, location:1, destination:6})" href="/jobs?med=site-ui&amp;ref=jobs-tab" id="nav-jobs">
# Jobs        </a>
# </li>
# </ol>
# </li>
# <li>
# <ol class="nav-links">
# <li class="p6">
# <div class="ba bc-black-2 bar-sm p16 grid fd-column ps-relative overflow-hidden">
# <strong class="grid--cell">Teams</strong>
# <span class="grid--cell mt2 fs-caption fc-medium">Q&amp;A for work </span>
# <a class="js-gps-track s-btn s-btn__outlined ta-center grid--cell mt12" data-ga='["teams traffic","left nav cta","stackoverflow.com/teams",null,{"dimension4":"teams"}]' data-gps-track="teams.create.left-sidenav.click({ CampaignType: None})" href="https://stackoverflow.com/teams">
#                                                     Learn More
#                                                 </a>
# <div class="ps-absolute t4 rn6">
# <svg fill="none" height="49" width="53" xmlns="http://www.w3.org/2000/svg"><path d="M49 11l.2 31H18.9L9 49v-7H4V8h31" fill="#CCEAFF"></path><path d="M44.5 19v-.3l-.2-.1-18-13-.1-.1H.5v33h4V46l.8-.6 9.9-6.9h29.3V19z" stroke="#1060E1" stroke-miterlimit="10"></path><path d="M31 2l6-1.5 7 2V38H14.9L5 45v-7H1V6h25l5-4z" fill="#fff"></path><path d="M7 16.5h13m-13 6h14m-14 6h18" stroke="#1060E1" stroke-miterlimit="10"></path><path d="M39 30a14 14 0 1 0 0-28 14 14 0 0 0 0 28z" fill="#FFB935"></path><path d="M50.5 14a13.5 13.5 0 1 1-27 0 13.5 13.5 0 0 1 27 0z" stroke="#F48024" stroke-miterlimit="10"></path><path d="M32.5 21.5v-8h9v8h-9zm2-9.5V9.3A2.5 2.5 0 0 1 37 6.8a2.5 2.5 0 0 1 2.5 2.5V12h-5zm2 3v2m1-2v2" stroke="#fff" stroke-miterlimit="10"></path></svg>
# </div>
# </div>
# </li>
# </ol>
# </li>
# </ol>
# </nav>
# </div>
# </div>
# <div class="snippet-hidden" id="content">
# <div class="inner-content">
# <div id="mainbar">
# <div class="grid">
# <h1 class="grid--cell fl1 fs-headline1">
#                     Top Questions
#             </h1>
# <div aria-label="ask new question" class="pl8 aside-cta grid--cell" role="navigation">
# <a class="d-inline-flex ai-center ws-nowrap s-btn s-btn__primary" href="/questions/ask">
#             Ask Question
#         </a>
# </div>
# </div>
# <div class="grid ai-center mb16">
# <div class="grid--cell fl1 fs-body3"></div>
# <div class="grid--cell">
# <div class="grid tabs-filter s-btn-group">
# <a class="youarehere is-selected grid--cell s-btn s-btn__muted s-btn__outlined py8 ws-nowrap" data-nav-xhref="" data-shortcut="" data-value="interesting" href="?tab=interesting" title="Questions that may be of interest to you based on your history and tag preference">
#             Interesting</a>
# <a class="grid--cell s-btn s-btn__muted s-btn__outlined py8 ws-nowrap" data-nav-xhref="" data-shortcut="B" data-value="featured" href="?tab=featured" title="Questions with an active bounty">
# <span class="bounty-indicator-tab">362</span>            Featured</a>
# <a class="grid--cell s-btn s-btn__muted s-btn__outlined py8 ws-nowrap" data-nav-xhref="" data-shortcut="H" data-value="hot" href="?tab=hot" title="Questions with the most views, answers, and votes over the last few days">
#             Hot</a>
# <a class="grid--cell s-btn s-btn__muted s-btn__outlined py8 ws-nowrap" data-nav-xhref="" data-shortcut="W" data-value="week" href="?tab=week" title="Questions with the most views, answers, and votes this week">
#             Week</a>
# <a class="grid--cell s-btn s-btn__muted s-btn__outlined py8 ws-nowrap" data-nav-xhref="" data-shortcut="M" data-value="month" href="?tab=month" title="Questions with the most views, answers, and votes this month">
#             Month</a>
# </div>
# </div>
# </div>
# <div class="flush-left" id="qlist-wrapper">
# <div id="question-mini-list">
# <div>
# <div class="question-summary narrow" id="question-summary-54824389">
# <div class="cp" onclick="window.location.href='/questions/54824389/wndproc-in-radwindow-wpf'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="3 views">3</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824389/wndproc-in-radwindow-wpf">WndProc in RadWindow WPF</a></h3>
# <div class="tags t-cñ t-wpf t-telerik">
# <a class="post-tag" href="/questions/tagged/c%23" rel="tag" title="show questions tagged 'c#'">c#</a> <a class="post-tag" href="/questions/tagged/wpf" rel="tag" title="show questions tagged 'wpf'">wpf</a> <a class="post-tag" href="/questions/tagged/telerik" rel="tag" title="show questions tagged 'telerik'">telerik</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824389/wndproc-in-radwindow-wpf">modified <span class="relativetime" title="2019-02-22 09:58:12Z">35 secs ago</span></a>
# <a href="/users/8829944/henry-dv">henry.dv</a> <span class="reputation-score" dir="ltr" title="reputation score ">158</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824486">
# <div class="cp" onclick="window.location.href='/questions/54824486/open-social-logins-in-new-tab-instead-of-new-window-popup-window'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="2 views">2</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824486/open-social-logins-in-new-tab-instead-of-new-window-popup-window">Open Social Login's in new tab instead of new window/popup window</a></h3>
# <div class="tags t-angular t-angular-social-plugin">
# <a class="post-tag" href="/questions/tagged/angular" rel="tag" title="show questions tagged 'angular'">angular</a> <a class="post-tag" href="/questions/tagged/angular-social-plugin" rel="tag" title="show questions tagged 'angular-social-plugin'">angular-social-plugin</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824486/open-social-logins-in-new-tab-instead-of-new-window-popup-window">asked <span class="relativetime" title="2019-02-22 09:58:02Z">46 secs ago</span></a>
# <a href="/users/3916831/kenny">Kenny</a> <span class="reputation-score" dir="ltr" title="reputation score ">1,798</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824482">
# <div class="cp" onclick="window.location.href='/questions/54824482/nsdateformatter-for-2-types-of-utc-string'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="3 views">3</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824482/nsdateformatter-for-2-types-of-utc-string">NSDateFormatter for 2 types of UTC string</a></h3>
# <div class="tags t-ios t-objective-c t-xcode t-nsstring t-nsdate">
# <a class="post-tag" href="/questions/tagged/ios" rel="tag" title="show questions tagged 'ios'">ios</a> <a class="post-tag" href="/questions/tagged/objective-c" rel="tag" title="show questions tagged 'objective-c'">objective-c</a> <a class="post-tag" href="/questions/tagged/xcode" rel="tag" title="show questions tagged 'xcode'">xcode</a> <a class="post-tag" href="/questions/tagged/nsstring" rel="tag" title="show questions tagged 'nsstring'">nsstring</a> <a class="post-tag" href="/questions/tagged/nsdate" rel="tag" title="show questions tagged 'nsdate'">nsdate</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824482/nsdateformatter-for-2-types-of-utc-string">asked <span class="relativetime" title="2019-02-22 09:57:47Z">1 min ago</span></a>
# <a href="/users/1722760/halpo">Halpo</a> <span class="reputation-score" dir="ltr" title="reputation score ">1,361</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824480">
# <div class="cp" onclick="window.location.href='/questions/54824480/how-to-modify-componentss-structures-using-directives'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="3 views">3</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824480/how-to-modify-componentss-structures-using-directives">How to modify components's structures using directives?</a></h3>
# <div class="tags t-angular">
# <a class="post-tag" href="/questions/tagged/angular" rel="tag" title="show questions tagged 'angular'">angular</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824480/how-to-modify-componentss-structures-using-directives">asked <span class="relativetime" title="2019-02-22 09:57:46Z">1 min ago</span></a>
# <a href="/users/7429175/dc-p8">dc-p8</a> <span class="reputation-score" dir="ltr" title="reputation score ">176</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824479">
# <div class="cp" onclick="window.location.href='/questions/54824479/how-to-add-data-of-two-different-serializers-to-be-passed-as-refrence-in-django'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="2 views">2</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824479/how-to-add-data-of-two-different-serializers-to-be-passed-as-refrence-in-django">How to add data of two different serializers to be passed as refrence in Django Rest Framework</a></h3>
# <div class="tags t-django t-django-rest-framework t-django-serializer">
# <a class="post-tag" href="/questions/tagged/django" rel="tag" title="show questions tagged 'django'">django</a> <a class="post-tag" href="/questions/tagged/django-rest-framework" rel="tag" title="show questions tagged 'django-rest-framework'">django-rest-framework</a> <a class="post-tag" href="/questions/tagged/django-serializer" rel="tag" title="show questions tagged 'django-serializer'">django-serializer</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824479/how-to-add-data-of-two-different-serializers-to-be-passed-as-refrence-in-django">asked <span class="relativetime" title="2019-02-22 09:57:43Z">1 min ago</span></a>
# <a href="/users/4755440/paras">Paras</a> <span class="reputation-score" dir="ltr" title="reputation score ">463</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824478">
# <div class="cp" onclick="window.location.href='/questions/54824478/how-to-automate-otp-using-robotframework'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="4 views">4</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824478/how-to-automate-otp-using-robotframework">How to automate OTP using robotframework?</a></h3>
# <div class="tags t-python t-pycharm t-robotframework">
# <a class="post-tag" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a> <a class="post-tag" href="/questions/tagged/pycharm" rel="tag" title="show questions tagged 'pycharm'">pycharm</a> <a class="post-tag" href="/questions/tagged/robotframework" rel="tag" title="show questions tagged 'robotframework'">robotframework</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824478/how-to-automate-otp-using-robotframework">asked <span class="relativetime" title="2019-02-22 09:57:42Z">1 min ago</span></a>
# <a href="/users/11100807/sunny">Sunny</a> <span class="reputation-score" dir="ltr" title="reputation score ">1</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824368">
# <div class="cp" onclick="window.location.href='/questions/54824368/how-can-i-connect-two-pickers-as-city-district-in-react-native'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="7 views">7</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824368/how-can-i-connect-two-pickers-as-city-district-in-react-native">How can I connect two pickers as city-district in React-Native?</a></h3>
# <div class="tags t-javascript t-react-native t-mobile">
# <a class="post-tag" href="/questions/tagged/javascript" rel="tag" title="show questions tagged 'javascript'">javascript</a> <a class="post-tag" href="/questions/tagged/react-native" rel="tag" title="show questions tagged 'react-native'">react-native</a> <a class="post-tag" href="/questions/tagged/mobile" rel="tag" title="show questions tagged 'mobile'">mobile</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824368/how-can-i-connect-two-pickers-as-city-district-in-react-native">modified <span class="relativetime" title="2019-02-22 09:57:39Z">1 min ago</span></a>
# <a href="/users/3634538/jom">jom</a> <span class="reputation-score" dir="ltr" title="reputation score ">2,095</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824474">
# <div class="cp" onclick="window.location.href='/questions/54824474/c-overloading-operator-for-doublecomplex'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="4 views">4</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824474/c-overloading-operator-for-doublecomplex">C++ overloading operator+ for double+complex?</a></h3>
# <div class="tags t-cçç t-overloading">
# <a class="post-tag" href="/questions/tagged/c%2b%2b" rel="tag" title="show questions tagged 'c++'">c++</a> <a class="post-tag" href="/questions/tagged/overloading" rel="tag" title="show questions tagged 'overloading'">overloading</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824474/c-overloading-operator-for-doublecomplex">asked <span class="relativetime" title="2019-02-22 09:57:32Z">1 min ago</span></a>
# <a href="/users/10527541/laklaklkalkalk">laklaklkalkalk</a> <span class="reputation-score" dir="ltr" title="reputation score ">9</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824473">
# <div class="cp" onclick="window.location.href='/questions/54824473/checking-room-availability-using-codeigniter-query'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="4 views">4</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824473/checking-room-availability-using-codeigniter-query">Checking room availability using codeigniter query</a></h3>
# <div class="tags t-php t-sql t-codeigniter">
# <a class="post-tag" href="/questions/tagged/php" rel="tag" title="show questions tagged 'php'">php</a> <a class="post-tag" href="/questions/tagged/sql" rel="tag" title="show questions tagged 'sql'">sql</a> <a class="post-tag" href="/questions/tagged/codeigniter" rel="tag" title="show questions tagged 'codeigniter'">codeigniter</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824473/checking-room-availability-using-codeigniter-query">asked <span class="relativetime" title="2019-02-22 09:57:28Z">1 min ago</span></a>
# <a href="/users/9845283/nikhil-m">Nikhil M</a> <span class="reputation-score" dir="ltr" title="reputation score ">3</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-30862162">
# <div class="cp" onclick="window.location.href='/questions/30862162/otp-token-should-be-automatically-read-from-the-message'">
# <div class="votes">
# <div class="mini-counts"><span title="31 votes">31</span></div>
# <div>votes</div>
# </div>
# <div class="status answered">
# <div class="mini-counts"><span title="8 answers">8</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts hot"><span title="61075 views">61k</span></div>
# <div class="hot">views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/30862162/otp-token-should-be-automatically-read-from-the-message">OTP (token) should be automatically read from the message</a></h3>
# <div class="tags t-android t-otp">
# <a class="post-tag" href="/questions/tagged/android" rel="tag" title="show questions tagged 'android'"><img alt="" class="sponsor-tag-img" height="16" src="//i.stack.imgur.com/bk9VA.png" width="18"/>android</a> <a class="post-tag" href="/questions/tagged/otp" rel="tag" title="show questions tagged 'otp'">otp</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/30862162/otp-token-should-be-automatically-read-from-the-message/?lastactivity">modified <span class="relativetime" title="2019-02-22 09:57:24Z">1 min ago</span></a>
# <a href="/users/1537413/dika">Dika</a> <span class="reputation-score" dir="ltr" title="reputation score ">698</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54823769">
# <div class="cp" onclick="window.location.href='/questions/54823769/how-do-i-delete-namevaluepairs-in-a-json-request-using-retrofit'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status answered">
# <div class="mini-counts"><span title="3 answers">3</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="20 views">20</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54823769/how-do-i-delete-namevaluepairs-in-a-json-request-using-retrofit">How do I delete “nameValuePairs” in a JSON request using Retrofit?</a></h3>
# <div class="tags t-android t-retrofit">
# <a class="post-tag" href="/questions/tagged/android" rel="tag" title="show questions tagged 'android'"><img alt="" class="sponsor-tag-img" height="16" src="//i.stack.imgur.com/bk9VA.png" width="18"/>android</a> <a class="post-tag" href="/questions/tagged/retrofit" rel="tag" title="show questions tagged 'retrofit'">retrofit</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54823769/how-do-i-delete-namevaluepairs-in-a-json-request-using-retrofit/?lastactivity">modified <span class="relativetime" title="2019-02-22 09:57:22Z">1 min ago</span></a>
# <a href="/users/9293029/viraj-patel">Viraj Patel</a> <span class="reputation-score" dir="ltr" title="reputation score ">860</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54823846">
# <div class="cp" onclick="window.location.href='/questions/54823846/dplyr-left-join-does-not-work-with-a-character-objects-as-the-lhs-variable'">
# <div class="votes">
# <div class="mini-counts"><span title="4 votes">4</span></div>
# <div>votes</div>
# </div>
# <div class="status answered">
# <div class="mini-counts"><span title="1 answer">1</span></div>
# <div>answer</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="23 views">23</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54823846/dplyr-left-join-does-not-work-with-a-character-objects-as-the-lhs-variable">dplyr `left_join()` does not work with a character objects as the LHS variable</a></h3>
# <div class="tags t-r t-join t-dplyr t-left-join">
# <a class="post-tag" href="/questions/tagged/r" rel="tag" title="show questions tagged 'r'">r</a> <a class="post-tag" href="/questions/tagged/join" rel="tag" title="show questions tagged 'join'">join</a> <a class="post-tag" href="/questions/tagged/dplyr" rel="tag" title="show questions tagged 'dplyr'">dplyr</a> <a class="post-tag" href="/questions/tagged/left-join" rel="tag" title="show questions tagged 'left-join'">left-join</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54823846/dplyr-left-join-does-not-work-with-a-character-objects-as-the-lhs-variable/?lastactivity">modified <span class="relativetime" title="2019-02-22 09:57:22Z">1 min ago</span></a>
# <a href="/users/10323798/nelsongon">NelsonGon</a> <span class="reputation-score" dir="ltr" title="reputation score ">2,762</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824469">
# <div class="cp" onclick="window.location.href='/questions/54824469/how-to-automatically-send-jwt-token-collected-in-previous-request-in-postman'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="3 views">3</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824469/how-to-automatically-send-jwt-token-collected-in-previous-request-in-postman">How to automatically send JWT token collected in previous request in Postman</a></h3>
# <div class="tags t-automation t-jwt t-postman">
# <a class="post-tag" href="/questions/tagged/automation" rel="tag" title="show questions tagged 'automation'">automation</a> <a class="post-tag" href="/questions/tagged/jwt" rel="tag" title="show questions tagged 'jwt'">jwt</a> <a class="post-tag" href="/questions/tagged/postman" rel="tag" title="show questions tagged 'postman'">postman</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824469/how-to-automatically-send-jwt-token-collected-in-previous-request-in-postman">asked <span class="relativetime" title="2019-02-22 09:57:02Z">1 min ago</span></a>
# <a href="/users/2899889/milang">MilanG</a> <span class="reputation-score" dir="ltr" title="reputation score ">4,840</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824468">
# <div class="cp" onclick="window.location.href='/questions/54824468/what-is-the-difference-between-the-following-two-expressions-in-golang'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="3 views">3</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824468/what-is-the-difference-between-the-following-two-expressions-in-golang">What is the difference between the following two expressions in golang?</a></h3>
# <div class="tags t-go">
# <a class="post-tag" href="/questions/tagged/go" rel="tag" title="show questions tagged 'go'">go</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824468/what-is-the-difference-between-the-following-two-expressions-in-golang">asked <span class="relativetime" title="2019-02-22 09:57:01Z">1 min ago</span></a>
# <a href="/users/7592760/holen">Holen</a> <span class="reputation-score" dir="ltr" title="reputation score ">1</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824465">
# <div class="cp" onclick="window.location.href='/questions/54824465/a-groupby-and-aggregation-function-is-giving-an-unexpected-result'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="3 views">3</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824465/a-groupby-and-aggregation-function-is-giving-an-unexpected-result">A groupby and aggregation function is giving an unexpected result</a></h3>
# <div class="tags t-python-3ûx t-group-by t-operators t-aggregate t-itertools">
# <a class="post-tag" href="/questions/tagged/python-3.x" rel="tag" title="show questions tagged 'python-3.x'">python-3.x</a> <a class="post-tag" href="/questions/tagged/group-by" rel="tag" title="show questions tagged 'group-by'">group-by</a> <a class="post-tag" href="/questions/tagged/operators" rel="tag" title="show questions tagged 'operators'">operators</a> <a class="post-tag" href="/questions/tagged/aggregate" rel="tag" title="show questions tagged 'aggregate'">aggregate</a> <a class="post-tag" href="/questions/tagged/itertools" rel="tag" title="show questions tagged 'itertools'">itertools</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824465/a-groupby-and-aggregation-function-is-giving-an-unexpected-result">asked <span class="relativetime" title="2019-02-22 09:56:52Z">1 min ago</span></a>
# <a href="/users/8961468/jama-hussein-mohamud">Jama Hussein Mohamud</a> <span class="reputation-score" dir="ltr" title="reputation score ">6</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54789581">
# <div class="cp" onclick="window.location.href='/questions/54789581/how-to-display-the-array-and-if-any-value-is-selected-that-to-be-displayed'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status answered">
# <div class="mini-counts"><span title="1 answer">1</span></div>
# <div>answer</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="24 views">24</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54789581/how-to-display-the-array-and-if-any-value-is-selected-that-to-be-displayed">How to display the array and if any value is selected that to be displayed?</a></h3>
# <div class="tags t-angularjs">
# <a class="post-tag" href="/questions/tagged/angularjs" rel="tag" title="show questions tagged 'angularjs'">angularjs</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54789581/how-to-display-the-array-and-if-any-value-is-selected-that-to-be-displayed/?lastactivity">answered <span class="relativetime" title="2019-02-22 09:56:40Z">2 mins ago</span></a>
# <a href="/users/8757883/akber-iqbal">Akber Iqbal</a> <span class="reputation-score" dir="ltr" title="reputation score ">2,386</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824459">
# <div class="cp" onclick="window.location.href='/questions/54824459/im-trying-to-use-scala-implementation-of-iforest-https-github-com-titicaca-sp'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="4 views">4</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824459/im-trying-to-use-scala-implementation-of-iforest-https-github-com-titicaca-sp">I'm trying to use scala implementation of IForest https://github.com/titicaca/spark-iforest,it give me these errors:</a></h3>
# <div class="tags t-scala t-apache-spark">
# <a class="post-tag" href="/questions/tagged/scala" rel="tag" title="show questions tagged 'scala'">scala</a> <a class="post-tag" href="/questions/tagged/apache-spark" rel="tag" title="show questions tagged 'apache-spark'">apache-spark</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54824459/im-trying-to-use-scala-implementation-of-iforest-https-github-com-titicaca-sp">asked <span class="relativetime" title="2019-02-22 09:56:37Z">2 mins ago</span></a>
# <a href="/users/11100801/cking">cking</a> <span class="reputation-score" dir="ltr" title="reputation score ">1</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54822924">
# <div class="cp" onclick="window.location.href='/questions/54822924/group-by-distinct-users-mental-block'">
# <div class="votes">
# <div class="mini-counts"><span title="-1 votes">-1</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="24 views">24</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54822924/group-by-distinct-users-mental-block">Group by distinct users - mental block</a></h3>
# <div class="tags t-mysql">
# <a class="post-tag" href="/questions/tagged/mysql" rel="tag" title="show questions tagged 'mysql'">mysql</a>
# </div>
# <div class="started">
# <a class="started-link" href="/questions/54822924/group-by-distinct-users-mental-block">modified <span class="relativetime" title="2019-02-22 09:56:29Z">2 mins ago</span></a>
# <a href="/users/11082315/liam-cox">Liam Cox</a> <span class="reputation-score" dir="ltr" title="reputation score ">6</span>
# </div>
# </div>
# </div>
# <div class="question-summary narrow" id="question-summary-54824456">
# <div class="cp" onclick="window.location.href='/questions/54824456/could-not-resolve-org-nodejs-local-build-error'">
# <div class="votes">
# <div class="mini-counts"><span title="0 votes">0</span></div>
# <div>votes</div>
# </div>
# <div class="status unanswered">
# <div class="mini-counts"><span title="0 answers">0</span></div>
# <div>answers</div>
# </div>
# <div class="views">
# <div class="mini-counts"><span title="5 views">5</span></div>
# <div>views</div>
# </div>
# </div>
# <div class="summary">
# <h3><a class="question-hyperlink" href="/questions/54824456/could-not-resolve-org-nodejs-local-build-error">Could not resolve org.nodejs : Local build error</a></h3>
# <div class="tags t-nodeûjs t-angular t-gradle">
# ...
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://raspberrypi.stackexchange.com" title="users and developers of hardware and software for Raspberry Pi">Raspberry Pi</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://ru.stackoverflow.com" title="программистов">Stack Overflow на русском</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://codegolf.stackexchange.com" title="programming puzzle enthusiasts and code golfers">Programming Puzzles &amp; Code Golf</a></li>
# </ul></div><div class="site-footer--col site-footer--category js-footer-col" data-name="Technology"><ul class="-list">
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://es.stackoverflow.com" title="programadores y profesionales de la informática">Stack Overflow en español</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://ethereum.stackexchange.com" title="users of Ethereum, the decentralized application platform and smart contract enabled blockchain">Ethereum</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://datascience.stackexchange.com" title="Data science professionals, Machine Learning specialists, and those interested in learning more about the field">Data Science</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://arduino.stackexchange.com" title="developers of open-source hardware and software that is compatible with Arduino">Arduino</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://bitcoin.stackexchange.com" title="Bitcoin crypto-currency enthusiasts">Bitcoin</a></li>
# <li class="-item">
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 26 })" href="https://stackexchange.com/sites#technology">
# <strong>
#                             more (31)
#                         </strong>
# </a>
# </li>
# </ul>
# </div>
# <div class="site-footer--col site-footer--category js-footer-col" data-name="Life / Arts">
# <ul class="-list">
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://photo.stackexchange.com" title="professional, enthusiast and amateur photographers">Photography</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://scifi.stackexchange.com" title="science fiction and fantasy enthusiasts">Science Fiction &amp; Fantasy</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://graphicdesign.stackexchange.com" title="Graphic Design professionals, students, and enthusiasts">Graphic Design</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://movies.stackexchange.com" title="movie and tv enthusiasts">Movies &amp; TV</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://music.stackexchange.com" title="musicians, students, and enthusiasts">Music: Practice &amp; Theory</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://worldbuilding.stackexchange.com" title="writers/artists using science, geography and culture to construct imaginary worlds and settings">Worldbuilding</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://cooking.stackexchange.com" title="professional and amateur chefs">Seasoned Advice (cooking)</a></li>
# </ul></div><div class="site-footer--col site-footer--category js-footer-col" data-name="Life / Arts"><ul class="-list">
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://diy.stackexchange.com" title="contractors and serious DIYers">Home Improvement</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://money.stackexchange.com" title="people who want to be financially literate">Personal Finance &amp; Money</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://academia.stackexchange.com" title="academics and those enrolled in higher education">Academia</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://law.stackexchange.com" title="legal professionals, students, and others with experience or interest in law">Law</a></li>
# <li class="-item">
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 26 })" href="https://stackexchange.com/sites#lifearts">
# <strong>
#                             more (15)
#                         </strong>
# </a>
# </li>
# </ul>
# </div>
# <div class="site-footer--col site-footer--category js-footer-col" data-name="Culture / Recreation">
# <ul class="-list">
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://english.stackexchange.com" title="linguists, etymologists, and serious English language enthusiasts">English Language &amp; Usage</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://skeptics.stackexchange.com" title="scientific skepticism">Skeptics</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://judaism.stackexchange.com" title="those who base their lives on Jewish law and tradition and anyone interested in learning more">Mi Yodeya (Judaism)</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://travel.stackexchange.com" title="road warriors and seasoned travelers">Travel</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://christianity.stackexchange.com" title="committed Christians, experts in Christianity and those interested in learning more">Christianity</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://ell.stackexchange.com" title="speakers of other languages learning English">English Language Learners</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://japanese.stackexchange.com" title="students, teachers, and linguists wanting to discuss the finer points of the Japanese language">Japanese Language</a></li>
# </ul></div><div class="site-footer--col site-footer--category js-footer-col" data-name="Culture / Recreation"><ul class="-list">
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://gaming.stackexchange.com" title="passionate videogamers on all platforms">Arqade (gaming)</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://bicycles.stackexchange.com" title="people who build and repair bicycles, people who train cycling, or commute on bicycles">Bicycles</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://rpg.stackexchange.com" title="gamemasters and players of tabletop, paper-and-pencil role-playing games">Role-playing Games</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://anime.stackexchange.com" title="anime and manga fans">Anime &amp; Manga</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://puzzling.stackexchange.com" title="those who create, solve, and study puzzles">Puzzling</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://mechanics.stackexchange.com" title="mechanics and DIY enthusiast owners of cars, trucks, and motorcycles">Motor Vehicle Maintenance &amp; Repair</a></li>
# <li class="-item">
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 26 })" href="https://stackexchange.com/sites#culturerecreation">
# <strong>
#                             more (33)
#                         </strong>
# </a>
# </li>
# </ul>
# </div>
# <div class="site-footer--col site-footer--category js-footer-col" data-name="Science">
# <ul class="-list">
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://mathoverflow.net" title="professional mathematicians">MathOverflow</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://math.stackexchange.com" title="people studying math at any level and professionals in related fields">Mathematics</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://stats.stackexchange.com" title="people interested in statistics, machine learning, data analysis, data mining, and data visualization">Cross Validated (stats)</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://cstheory.stackexchange.com" title="theoretical computer scientists and researchers in related fields">Theoretical Computer Science</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://physics.stackexchange.com" title="active researchers, academics and students of physics">Physics</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://chemistry.stackexchange.com" title="scientists, academics, teachers, and students in the field of chemistry">Chemistry</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://biology.stackexchange.com" title="biology researchers, academics, and students">Biology</a></li>
# </ul></div><div class="site-footer--col site-footer--category js-footer-col" data-name="Science"><ul class="-list">
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://cs.stackexchange.com" title="students, researchers and practitioners of computer science">Computer Science</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://philosophy.stackexchange.com" title="those interested in the study of the fundamental nature of knowledge, reality, and existence">Philosophy</a></li>
# <li class="-item">
# <a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 26 })" href="https://stackexchange.com/sites#science">
# <strong>
#                             more (10)
#                         </strong>
# </a>
# </li>
# </ul>
# </div>
# <div class="site-footer--col site-footer--category js-footer-col" data-name="Other">
# <ul class="-list">
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://meta.stackexchange.com" title="meta-discussion of the Stack Exchange family of Q&amp;A websites">Meta Stack Exchange</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://stackapps.com" title="apps, scripts, and development with the Stack Exchange API">Stack Apps</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://api.stackexchange.com" title="programmatic interaction with Stack Exchange sites">API</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://data.stackexchange.com" title="querying Stack Exchange data using SQL">Data</a></li>
# <li class="-item"><a class="-link js-gps-track" data-gps-track="footer.click({ location: 0, link: 25 })" href="https://area51.stackexchange.com" title="proposing new sites in the Stack Exchange network">Area 51</a></li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="site-footer--copyright fs-fine">
# <ul class="-list">
# <li class="-item"><a class="js-gps-track -link" data-gps-track="footer.click({ location: 1, link:4 })" href="https://stackoverflow.blog?blb=1">Blog</a></li>
# <li class="-item"><a class="-link" href="https://www.facebook.com/officialstackoverflow/">Facebook</a></li>
# <li class="-item"><a class="-link" href="https://twitter.com/stackoverflow">Twitter</a></li>
# <li class="-item"><a class="-link" href="https://linkedin.com/company/stack-overflow">LinkedIn</a></li>
# </ul>
# <p class="mt-auto mb24">
# site design / logo © 2019 Stack Exchange Inc; user contributions licensed under <a href="https://creativecommons.org/licenses/by-sa/3.0/" rel="license">cc by-sa 3.0</a>
#                             with <a href="https://stackoverflow.blog/2009/06/25/attribution-required/" rel="license">attribution required</a>.
#                     <span id="svnrev">rev 2019.2.22.32929</span>
# </p>
# </div>
# </div>
# </footer>
# <script>StackExchange.ready(function () { StackExchange.responsiveness.addSwitcher(); })</script>
# <noscript>
# <div id="noscript-warning">Stack Overflow works best with JavaScript enabled
#             <img alt="" class="dno" src="https://pixel.quantserve.com/pixel/p-c1rF4kxgLUzNc.gif"/>
# </div>
# </noscript>
# <script>
#             (function(i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function() { (i[r].q = i[r].q || []).push(arguments) }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m);
#             })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#             StackExchange.ready(function () {
#
#                 StackExchange.ga.init({
#                     sendTitles: true,
#                     tracker: window.ga,
#                     trackingCodes: [
#                         'UA-108242619-1'
#                     ]
#                 });
#
#
#
#
#                     StackExchange.ga.setDimension('dimension3', 'Home/Index');
#
#
#                 StackExchange.ga.trackPageView();
#             });
#
# /**/
#
#             var _qevents = _qevents || [],
#             _comscore = _comscore || [];
#             (function() {
#                 var ssl = 'https:' == document.location.protocol,
#                     s = document.getElementsByTagName('script')[0],
#                     qc = document.createElement('script');
#                  qc.async = true;
#                     qc.src = (ssl ? 'https://secure' : 'http://edge') + '.quantserve.com/quant.js';
#                     s.parentNode.insertBefore(qc, s);
#                     _qevents.push({ qacct: "p-c1rF4kxgLUzNc" });
# /**/
#                  var sc = document.createElement('script');
#                     sc.async = true;
#                     sc.src = (ssl ? 'https://sb' : 'http://b') + '.scorecardresearch.com/beacon.js';
#                     s.parentNode.insertBefore(sc, s);
#                     _comscore.push({ c1: "2", c2: "17440561" });
#             })();
#
#
# </script>
# </body>
# </html>

# %%
print("Title: ", soup.title,
      "\nText: ", soup.title.text,
     "\nname: ", soup.title.name)
# Out:
# Title:  <title>Stack Overflow - Where Developers Learn, Share, &amp; Build Careers</title>
# Text:  Stack Overflow - Where Developers Learn, Share, & Build Careers
# name:  title

# %%
parag = soup.find_all('p') # get all p tag
for p in parag:
    print(p.text)
# Out:
#                     By using our site, you acknowledge that you have read and understand our Cookie Policy, Privacy Policy, and our Terms of Service.
#
#
# site design / logo © 2019 Stack Exchange Inc; user contributions licensed under cc by-sa 3.0
#                             with attribution required.
#                     rev 2019.2.22.32929

# %%
# Get all links
for url in soup.find_all('a'):
    if url.get('href') == '#':
        continue
    print(url.get('href'))
# Out:
# https://stackoverflow.com
# https://stackexchange.com/users/?tab=inbox
# https://stackexchange.com/users/?tab=reputation
# https://stackexchange.com
# https://stackoverflow.com/users/login?ssrc=head&returnurl=https%3a%2f%2fstackoverflow.com%2f
# https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent
# https://stackoverflow.com
# https://stackoverflow.com
# https://stackoverflow.com/help
# https://chat.stackoverflow.com
# https://meta.stackoverflow.com
# https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent
# https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=https%3a%2f%2fstackoverflow.com%2f
# https://stackexchange.com/sites
# https://stackoverflow.blog
# /tour
# /help
# https://meta.stackoverflow.com
# https://stackoverflow.com/company/about
# https://www.stackoverflowbusiness.com/?ref=topbar_help
# https://stackoverflow.com/legal/cookie-policy
# https://stackoverflow.com/legal/privacy-policy
# https://stackoverflow.com/legal/terms-of-service/public
# None
# /
# /questions
# /tags
# /users
# /jobs?med=site-ui&ref=jobs-tab
# https://stackoverflow.com/teams
# /questions/ask
# ?tab=interesting
# ?tab=featured
# ?tab=hot
# ?tab=week
# ?tab=month
# /questions/54824389/wndproc-in-radwindow-wpf
# /questions/tagged/c%23
# /questions/tagged/wpf
# /questions/tagged/telerik
# /questions/54824389/wndproc-in-radwindow-wpf
# /users/8829944/henry-dv
# /questions/54824486/open-social-logins-in-new-tab-instead-of-new-window-popup-window
# /questions/tagged/angular
# /questions/tagged/angular-social-plugin
# /questions/54824486/open-social-logins-in-new-tab-instead-of-new-window-popup-window
# /users/3916831/kenny
# /questions/54824482/nsdateformatter-for-2-types-of-utc-string
# /questions/tagged/ios
# /questions/tagged/objective-c
# /questions/tagged/xcode
# /questions/tagged/nsstring
# /questions/tagged/nsdate
# /questions/54824482/nsdateformatter-for-2-types-of-utc-string
# /users/1722760/halpo
# /questions/54824480/how-to-modify-componentss-structures-using-directives
# /questions/tagged/angular
# /questions/54824480/how-to-modify-componentss-structures-using-directives
# /users/7429175/dc-p8
# /questions/54824479/how-to-add-data-of-two-different-serializers-to-be-passed-as-refrence-in-django
# /questions/tagged/django
# /questions/tagged/django-rest-framework
# /questions/tagged/django-serializer
# /questions/54824479/how-to-add-data-of-two-different-serializers-to-be-passed-as-refrence-in-django
# /users/4755440/paras
# /questions/54824478/how-to-automate-otp-using-robotframework
# /questions/tagged/python
# /questions/tagged/pycharm
# /questions/tagged/robotframework
# /questions/54824478/how-to-automate-otp-using-robotframework
# /users/11100807/sunny
# /questions/54824368/how-can-i-connect-two-pickers-as-city-district-in-react-native
# /questions/tagged/javascript
# /questions/tagged/react-native
# /questions/tagged/mobile
# /questions/54824368/how-can-i-connect-two-pickers-as-city-district-in-react-native
# /users/3634538/jom
# /questions/54824474/c-overloading-operator-for-doublecomplex
# /questions/tagged/c%2b%2b
# /questions/tagged/overloading
# /questions/54824474/c-overloading-operator-for-doublecomplex
# /users/10527541/laklaklkalkalk
# /questions/54824473/checking-room-availability-using-codeigniter-query
# /questions/tagged/php
# /questions/tagged/sql
# /questions/tagged/codeigniter
# /questions/54824473/checking-room-availability-using-codeigniter-query
# /users/9845283/nikhil-m
# /questions/30862162/otp-token-should-be-automatically-read-from-the-message
# /questions/tagged/android
# /questions/tagged/otp
# /questions/30862162/otp-token-should-be-automatically-read-from-the-message/?lastactivity
# /users/1537413/dika
# /questions/54823769/how-do-i-delete-namevaluepairs-in-a-json-request-using-retrofit
# /questions/tagged/android
# /questions/tagged/retrofit
# /questions/54823769/how-do-i-delete-namevaluepairs-in-a-json-request-using-retrofit/?lastactivity
# /users/9293029/viraj-patel
# /questions/54823846/dplyr-left-join-does-not-work-with-a-character-objects-as-the-lhs-variable
# /questions/tagged/r
# /questions/tagged/join
# /questions/tagged/dplyr
# /questions/tagged/left-join
# /questions/54823846/dplyr-left-join-does-not-work-with-a-character-objects-as-the-lhs-variable/?lastactivity
# /users/10323798/nelsongon
# /questions/54824469/how-to-automatically-send-jwt-token-collected-in-previous-request-in-postman
# /questions/tagged/automation
# /questions/tagged/jwt
# /questions/tagged/postman
# /questions/54824469/how-to-automatically-send-jwt-token-collected-in-previous-request-in-postman
# /users/2899889/milang
# /questions/54824468/what-is-the-difference-between-the-following-two-expressions-in-golang
# /questions/tagged/go
# /questions/54824468/what-is-the-difference-between-the-following-two-expressions-in-golang
# /users/7592760/holen
# /questions/54824465/a-groupby-and-aggregation-function-is-giving-an-unexpected-result
# /questions/tagged/python-3.x
# /questions/tagged/group-by
# /questions/tagged/operators
# /questions/tagged/aggregate
# /questions/tagged/itertools
# /questions/54824465/a-groupby-and-aggregation-function-is-giving-an-unexpected-result
# /users/8961468/jama-hussein-mohamud
# /questions/54789581/how-to-display-the-array-and-if-any-value-is-selected-that-to-be-displayed
# /questions/tagged/angularjs
# /questions/54789581/how-to-display-the-array-and-if-any-value-is-selected-that-to-be-displayed/?lastactivity
# /users/8757883/akber-iqbal
# /questions/54824459/im-trying-to-use-scala-implementation-of-iforest-https-github-com-titicaca-sp
# /questions/tagged/scala
# /questions/tagged/apache-spark
# /questions/54824459/im-trying-to-use-scala-implementation-of-iforest-https-github-com-titicaca-sp
# /users/11100801/cking
# /questions/54822924/group-by-distinct-users-mental-block
# /questions/tagged/mysql
# /questions/54822924/group-by-distinct-users-mental-block
# /users/11082315/liam-cox
# /questions/54824456/could-not-resolve-org-nodejs-local-build-error
# /questions/tagged/node.js
# /questions/tagged/angular
# /questions/tagged/gradle
# /questions/54824456/could-not-resolve-org-nodejs-local-build-error
# /users/849632/arun
# /questions/54823047/django-use-ajax-to-stream-the-results-of-a-query-set-with-annotations
# /questions/tagged/ajax
# /questions/tagged/django
# /questions/tagged/django-views
# /questions/54823047/django-use-ajax-to-stream-the-results-of-a-query-set-with-annotations
# /users/8939516/abedy
# /questions/54824455/python-struct-pack-returns-a-blank-value
# /questions/tagged/python
# /questions/tagged/arrays
# /questions/tagged/int
# /questions/tagged/hex
# /questions/tagged/struct.pack
# /questions/54824455/python-struct-pack-returns-a-blank-value
# /users/10710940/nmsilva
# /questions/54824451/powershell-hashtable-cannot-find-an-overload-for-add-and-the-argument-count
# /questions/tagged/powershell
# /questions/tagged/hashtable
# /questions/54824451/powershell-hashtable-cannot-find-an-overload-for-add-and-the-argument-count
# /users/6188783/nikita-fedorov
# /questions/54824449/scikit-learn-combining-output-of-tfidfvectorizer-and-onehotencoder-dimension
# /questions/tagged/python
# /questions/tagged/arrays
# /questions/tagged/pandas
# /questions/54824449/scikit-learn-combining-output-of-tfidfvectorizer-and-onehotencoder-dimension
# /users/11100657/colossal-harry
# /questions/33857134/checking-for-multiple-conditions-using-when-on-single-task-in-ansible
# /questions/tagged/ansible
# /questions/tagged/ansible-playbook
# /questions/33857134/checking-for-multiple-conditions-using-when-on-single-task-in-ansible/?lastactivity
# /users/2361308/hearen
# /questions/54824445/adding-cloudwatchevents-to-aws-lambda-function
# /questions/tagged/amazon-web-services
# /questions/tagged/aws-lambda
# /questions/tagged/aws-sdk
# /questions/tagged/amazon-cloudwatch
# /questions/54824445/adding-cloudwatchevents-to-aws-lambda-function
# /users/2464664/aab
# /questions/54765159/jenkins-unable-to-trigger-multiple-build-steps-in-parallel-using-the-execute-c
# /questions/tagged/jenkins
# /questions/tagged/robotframework
# /questions/54765159/jenkins-unable-to-trigger-multiple-build-steps-in-parallel-using-the-execute-c/?lastactivity
# /users/6110169/wojtek-t
# /questions/54824440/mongodb-shell-query-on-timestamp-range-not-working-in-java
# /questions/tagged/java
# /questions/tagged/mongodb
# /questions/54824440/mongodb-shell-query-on-timestamp-range-not-working-in-java
# /users/8052674/mike-mavor
# /questions/54824439/load-a-list-type-property-from-application-yml-into-java-pojo
# /questions/tagged/java
# /questions/tagged/spring-boot
# /questions/tagged/yaml
# /questions/54824439/load-a-list-type-property-from-application-yml-into-java-pojo
# /users/5715047/dhiraj-gandhi
# /questions/54824430/jupyter-autoreload-fails-when-changing-a-class
# /questions/tagged/python
# /questions/tagged/jupyter-notebook
# /questions/54824430/jupyter-autoreload-fails-when-changing-a-class
# /users/10511793/statistic-dean
# /questions/54824428/archiving-vs-build
# /questions/tagged/ios
# /questions/tagged/xcode
# /questions/54824428/archiving-vs-build
# /users/9816472/isaac
# /questions/54810905/calculate-responsive-width-of-element-to-define-size
# /questions/tagged/javascript
# /questions/tagged/reactjs
# /questions/tagged/react-slick
# /questions/54810905/calculate-responsive-width-of-element-to-define-size/?lastactivity
# /users/10380329/fabian
# /questions/45768392/woo-commerce-api-filter-product-by-category
# /questions/tagged/woocommerce
# /questions/tagged/woocommerce-rest-api
# /questions/45768392/woo-commerce-api-filter-product-by-category/?lastactivity
# /users/10833091/jad
# /questions/54824301/loading-and-using-swiper-4-4-6-in-laravel-5-7-bootstrap-4-3
# /questions/tagged/laravel-5
# /questions/tagged/bootstrap-4
# /questions/tagged/swiper
# /questions/54824301/loading-and-using-swiper-4-4-6-in-laravel-5-7-bootstrap-4-3
# /users/627035/klaaz
# /questions/54824418/yarn-container-launch-failed-with-exit-code-2
# /questions/tagged/java
# /questions/tagged/shell
# /questions/tagged/hadoop
# /questions/tagged/mapreduce
# /questions/tagged/yarn
# /questions/54824418/yarn-container-launch-failed-with-exit-code-2
# /users/11100764/min-l
# /questions/54821521/is-there-any-negative-impact-on-azure-app-service-performance-if-i-implement-th
# /questions/tagged/azure
# /questions/tagged/azure-web-sites
# /questions/tagged/azure-webjobs
# /questions/tagged/azure-application-insights
# /questions/tagged/azure-app-service-plans
# /questions/54821521/is-there-any-negative-impact-on-azure-app-service-performance-if-i-implement-th
# /users/5471259/pradeep
# /questions/54823650/cors-policy-dont-want-to-work-with-signalr-and-asp-net-core
# /questions/tagged/angular
# /questions/tagged/asp.net-core
# /questions/tagged/cors
# /questions/tagged/signalr
# /questions/tagged/angular7
# /questions/54823650/cors-policy-dont-want-to-work-with-signalr-and-asp-net-core
# /users/6440372/ashish-kamble
# /questions/3854310/how-to-convert-a-negative-number-to-positive
# /questions/tagged/python
# /questions/tagged/numbers
# /questions/tagged/absolute-value
# /questions/3854310/how-to-convert-a-negative-number-to-positive/?lastactivity
# /users/11100834/bako
# /questions/54824405/cant-read-environment-variables-in-heroku
# /questions/tagged/angular
# /questions/tagged/heroku
# /questions/tagged/deployment
# /questions/54824405/cant-read-environment-variables-in-heroku
# /users/7404090/snackoverflow
# /questions/54810801/how-to-define-the-microdata-markup-for-an-image-when-its-actually-a-picture-tag
# /questions/tagged/html
# /questions/tagged/image
# /questions/tagged/schema.org
# /questions/tagged/microdata
# /questions/tagged/picture-element
# /questions/54810801/how-to-define-the-microdata-markup-for-an-image-when-its-actually-a-picture-tag
# /users/4193157/carsten
# /questions/54824402/single-request-executes-under-different-threads
# /questions/tagged/multithreading
# /questions/tagged/spring-mvc
# /questions/tagged/logging
# /questions/tagged/mdc
# /questions/54824402/single-request-executes-under-different-threads
# /users/9940823/ashwani
# /questions/54824399/setting-java-property-for-jenkins-dgroovy-use-classvalue-true
# /questions/tagged/java
# /questions/tagged/jenkins
# /questions/54824399/setting-java-property-for-jenkins-dgroovy-use-classvalue-true
# /users/4016635/adem-dinarevi%c4%87
# /questions/54824398/programmatically-enable-static-website-on-azure-storage
# /questions/tagged/azure
# /questions/tagged/azure-web-sites
# /questions/tagged/azure-storage
# /questions/54824398/programmatically-enable-static-website-on-azure-storage
# /users/2393006/jerry
# /questions/54824395/vue-component-used-inside-elementui-message-box-cant-access-the-vuex-store
# /questions/tagged/vue.js
# /questions/tagged/element-ui
# /questions/54824395/vue-component-used-inside-elementui-message-box-cant-access-the-vuex-store
# /users/5517847/yariv-bar
# /questions/54824394/disable-hibernate-sequence-optimisations
# /questions/tagged/java
# /questions/tagged/hibernate
# /questions/tagged/jboss
# /questions/54824394/disable-hibernate-sequence-optimisations
# /users/2439611/firoz
# /questions/54824391/selecting-collections-not-working-in-my-nodejs-backend
# /questions/tagged/node.js
# /questions/tagged/mongodb
# /questions/tagged/express
# /questions/54824391/selecting-collections-not-working-in-my-nodejs-backend
# /users/9855875/favo-sa
# /questions/54824383/what-is-the-difference-between-cosmos-db-and-azure-storage-tables
# /questions/tagged/azure
# /questions/tagged/azure-storage
# /questions/tagged/azure-cosmosdb
# /questions/tagged/azure-table-storage
# /questions/54824383/what-is-the-difference-between-cosmos-db-and-azure-storage-tables
# /users/9631294/prateek
# /questions/54822680/is-was-there-such-a-function-as-cudamalloc2darray
# /questions/tagged/cuda
# /questions/tagged/textures
# /questions/54822680/is-was-there-such-a-function-as-cudamalloc2darray/?lastactivity
# /users/1485872/ander-biguri
# /questions/54824381/reading-body-of-a-bounce-in-outlook
# /questions/tagged/outlook
# /questions/tagged/bounce
# /questions/54824381/reading-body-of-a-bounce-in-outlook
# /users/618343/ralf-hildebrandt
# /questions/54824380/use-of-lower-and-upper-in-glassfish-ejb-ql
# /questions/tagged/jpa
# /questions/tagged/glassfish
# /questions/tagged/ejb
# /questions/tagged/ejbql
# /questions/54824380/use-of-lower-and-upper-in-glassfish-ejb-ql
# /users/8545495/magua
# /questions/54824377/how-do-i-get-the-exact-information-shown-in-about-section-of-a-software
# /questions/tagged/dll
# /questions/tagged/windows-installer
# /questions/tagged/registry
# /questions/tagged/exe
# /questions/tagged/source-code-protection
# /questions/54824377/how-do-i-get-the-exact-information-shown-in-about-section-of-a-software
# /users/6679345/sushant-rawat
# /questions/54824375/this-api-project-is-not-authorized-to-use-this-api-status-request-denied
# /questions/tagged/swift
# /questions/tagged/google-maps
# /questions/tagged/directions
# /questions/54824375/this-api-project-is-not-authorized-to-use-this-api-status-request-denied
# /users/7932197/swift
# /questions/54824373/delphis-stringgrid-with-more-columns-trunc-text
# /questions/tagged/delphi
# /questions/tagged/scrollbar
# /questions/tagged/tstringgrid
# /questions/54824373/delphis-stringgrid-with-more-columns-trunc-text
# /users/10663161/mnoga
# /questions/54824369/open-new-terminal-at-in-current-directory
# /questions/tagged/bash
# /questions/tagged/macos-mojave
# /questions/54824369/open-new-terminal-at-in-current-directory
# /users/596841/pookie
# /questions/54824319/i-keep-getting-errors-when-trying-to-execute-a-stored-procedure
# /questions/tagged/sql-server
# /questions/tagged/stored-procedures
# /questions/54824319/i-keep-getting-errors-when-trying-to-execute-a-stored-procedure/?lastactivity
# /users/4608204/ezlo
# /questions/54824366/how-to-resize-controls-in-visualization-in-kibana
# /questions/tagged/elasticsearch
# /questions/tagged/kibana
# /questions/tagged/kibana-5
# /questions/tagged/kibana-6
# /questions/54824366/how-to-resize-controls-in-visualization-in-kibana
# /users/10329052/shael
# /questions/54824365/apache-flink-use-yaml-file-as-properties-file
# /questions/tagged/properties
# /questions/tagged/yaml
# /questions/tagged/apache-flink
# /questions/tagged/flink-streaming
# /questions/54824365/apache-flink-use-yaml-file-as-properties-file
# /users/2311719/ali-ait-bachir
# /questions/2059014/converting-raw-audio-data-to-wav-with-scripting
# /questions/tagged/audio
# /questions/tagged/scripting
# /questions/2059014/converting-raw-audio-data-to-wav-with-scripting/?lastactivity
# /users/8924185/ahmad-zahabi
# /questions/54824359/how-to-dynamic-extract-some-part-of-string
# /questions/tagged/java
# /questions/tagged/string
# /questions/54824359/how-to-dynamic-extract-some-part-of-string
# /users/11100761/kek
# /questions/54824357/adding-good-quality-png-image-to-gmail-signature
# /questions/tagged/image
# /questions/tagged/email
# /questions/tagged/png
# /questions/54824357/adding-good-quality-png-image-to-gmail-signature
# /users/7637261/eddyg
# /questions/54824086/speech2text-and-text2speak-works-different-on-different-phones
# /questions/tagged/android
# /questions/tagged/android-speech-api
# /questions/54824086/speech2text-and-text2speak-works-different-on-different-phones
# /users/2649012/fant%c3%b4mas
# /questions/54824085/how-to-get-the-text-type
# /questions/tagged/haskell
# /questions/54824085/how-to-get-the-text-type/?lastactivity
# /users/10033674/karol-samborski
# /questions/54824149/how-to-check-postgres-master-server-state-in-standby-server-side
# /questions/tagged/postgresql
# /questions/tagged/database-replication
# /questions/tagged/postgresql-9.6
# /questions/54824149/how-to-check-postgres-master-server-state-in-standby-server-side
# /users/330315/a-horse-with-no-name
# /questions/54824341/how-to-populate-a-cluster-for-stress-testing-using-a-given-schema-in-cassandra
# /questions/tagged/cassandra
# /questions/tagged/populate
# /questions/tagged/cassandra-stress
# /questions/54824341/how-to-populate-a-cluster-for-stress-testing-using-a-given-schema-in-cassandra
# /users/6871727/luoleke
# /questions/54824327/is-vue-js-components-vm-el-constant-or-can-it-be-reassigned
# /questions/tagged/javascript
# /questions/tagged/vue.js
# /questions/tagged/vuejs2
# /questions/54824327/is-vue-js-components-vm-el-constant-or-can-it-be-reassigned
# /users/1030527/bernie
# /questions/54824326/ssrs-tablix-visibility-expression-executes-all-procedure-multiple-times
# /questions/tagged/reporting-services
# /questions/54824326/ssrs-tablix-visibility-expression-executes-all-procedure-multiple-times
# /users/6290322/shum
# /questions/54823674/relational-database-schema-design-for-metric-storage
# /questions/tagged/database
# /questions/tagged/database-design
# /questions/tagged/relational-database
# /questions/tagged/schema
# /questions/54823674/relational-database-schema-design-for-metric-storage
# /users/450159/sam-shiles
# /questions/54824323/databricks-job-cluster-per-pipeline-not-per-notebook-activity
# /questions/tagged/azure
# /questions/tagged/azure-data-factory
# /questions/tagged/databricks
# /questions/tagged/azure-databricks
# /questions/54824323/databricks-job-cluster-per-pipeline-not-per-notebook-activity
# /users/1891398/stev
# /questions/54823677/servicestack-multithreading-using-appselfhostbase-can-it-handle-concurrent-ca
# /questions/tagged/servicestack
# /questions/54823677/servicestack-multithreading-using-appselfhostbase-can-it-handle-concurrent-ca/?lastactivity
# /users/85785/mythz
# /questions/54823928/why-in-oracle-forms-based-on-procedure-query-does-not-return-any-values
# /questions/tagged/oracle
# /questions/tagged/oracleforms
# /questions/54823928/why-in-oracle-forms-based-on-procedure-query-does-not-return-any-values/?lastactivity
# /users/9097906/littlefoot
# /questions/54823457/unable-to-establish-socket-connection-in-react-native
# /questions/tagged/react-native
# /questions/tagged/socket.io
# /questions/54823457/unable-to-establish-socket-connection-in-react-native
# /users/7738433/harleen-kaur-arora
# /questions/54824264/convert-partitioned-mrg-myisam-table-to-innodb
# /questions/tagged/mysql
# /questions/tagged/innodb
# /questions/tagged/myisam
# /questions/54824264/convert-partitioned-mrg-myisam-table-to-innodb
# /users/652855/wmac
# /questions/54824263/pdf-document-is-shown-differently-on-adobe-acrobat-and-other-visors
# /questions/tagged/pdf
# /questions/tagged/digital-signature
# /questions/54824263/pdf-document-is-shown-differently-on-adobe-acrobat-and-other-visors
# /users/1517551/bardo
# /questions/54824261/use-an-azure-ssl-certificate-with-intercom-help-center
# /questions/tagged/azure
# /questions/tagged/ssl
# /questions/tagged/intercom
# /questions/54824261/use-an-azure-ssl-certificate-with-intercom-help-center
# /users/3647221/pmerlet
# /questions/54824007/dockerrun-aws-hardcoded-memory
# /questions/tagged/amazon-web-services
# /questions/tagged/docker
# /questions/tagged/amazon-elastic-beanstalk
# /questions/tagged/dockerrun.aws.json
# /questions/54824007/dockerrun-aws-hardcoded-memory
# /users/1561148/tgogos
# /questions/54824250/drawing-translated-paths-in-wrong-coordinates
# /questions/tagged/canvas
# /questions/54824250/drawing-translated-paths-in-wrong-coordinates
# /users/2668182/mevia
# /questions/54824213/secureboot-run-a-custom-kernel-initrd
# /questions/tagged/security
# /questions/tagged/kernel
# /questions/tagged/boot
# /questions/54824213/secureboot-run-a-custom-kernel-initrd
# /users/2937795/raddirad
# /questions/54824175/best-way-to-load-log-files-into-hadoop
# /questions/tagged/apache-spark
# /questions/tagged/hadoop
# /questions/tagged/hdfs
# /questions/tagged/spark-streaming
# /questions/tagged/flume
# /questions/54824175/best-way-to-load-log-files-into-hadoop
# /users/2384424/user2384424
# /questions/54824171/google-drive-fs-start-at-user-logon-foldername-executable-keeps-changing
# /questions/tagged/windows
# /questions/tagged/server
# /questions/tagged/drive
# /questions/54824171/google-drive-fs-start-at-user-logon-foldername-executable-keeps-changing
# /users/11100747/stefan-lemmens
# /questions/54824169/mustache-syntax-conditionally-print-html
# /questions/tagged/html
# /questions/tagged/json
# /questions/tagged/mustache
# /questions/54824169/mustache-syntax-conditionally-print-html
# /users/10383926/shan
# /questions/54791279/airflow-logs-are-not-showing-in-the-ui
# /questions/tagged/airflow
# /questions/tagged/airflow-scheduler
# /questions/54791279/airflow-logs-are-not-showing-in-the-ui
# /users/5512705/rawrplus
# /questions/54824124/target-unreachable-identifier-resolved-to-null-read-all-other-questions
# /questions/tagged/java
# /questions/tagged/maven
# /questions/tagged/java-ee
# /questions/tagged/payara
# /questions/tagged/java-ee-8
# /questions/54824124/target-unreachable-identifier-resolved-to-null-read-all-other-questions
# /users/1019181/wouter-van-acht
# /questions/54824114/gibbs-sampling-using-sklearn-package
# /questions/tagged/python
# /questions/54824114/gibbs-sampling-using-sklearn-package
# /users/10917718/konrad-s
# /questions/54823765/spring-rest-controller-inheritance
# /questions/tagged/spring
# /questions/tagged/spring-boot
# /questions/tagged/spring-mvc
# /questions/54823765/spring-rest-controller-inheritance/?lastactivity
# /users/8912667/fabien-mifsud
# /questions/53398656/android-wear-wearablelistenerservice-doesnt-trigger-on-android-8-oreo-when-app
# /questions/tagged/android
# /questions/tagged/wear-os
# /questions/tagged/android-wear-data-api
# /questions/tagged/android-wear-2.0
# /questions/53398656/android-wear-wearablelistenerservice-doesnt-trigger-on-android-8-oreo-when-app
# /users/4034572/albert-vila-calvo
# /questions/54824052/download-from-amazon-s3-aws-cli-or-boto3
# /questions/tagged/python
# /questions/tagged/amazon-s3
# /questions/tagged/boto3
# /questions/tagged/aws-cli
# /questions/tagged/python-3.7
# /questions/54824052/download-from-amazon-s3-aws-cli-or-boto3
# /users/9131095/czyzyk14
# /questions/54823989/how-do-you-use-confirm-dialogues-in-a-custom-laravel-nova-tool
# /questions/tagged/laravel
# /questions/tagged/vuejs2
# /questions/tagged/laravel-nova
# /questions/54823989/how-do-you-use-confirm-dialogues-in-a-custom-laravel-nova-tool
# /users/768510/thomas-nadin
# /questions/54823260/intsall4j-show-java-console
# /questions/tagged/install4j
# /questions/54823260/intsall4j-show-java-console/?lastactivity
# /users/936832/ingo-kegel
# /questions/54823896/change-model-field-if-requested-particular-url
# /questions/tagged/django-rest-framework
# /questions/tagged/django-polymorphic
# /questions/54823896/change-model-field-if-requested-particular-url
# /users/9312327/mohit-harshan
# /questions/54822595/difference-between-aegenerator-and-generator-in-the-segan-model-for-speech-enhan
# /questions/tagged/machine-learning
# /questions/tagged/deep-learning
# /questions/tagged/speech
# /questions/tagged/generative-adversarial-network
# /questions/54822595/difference-between-aegenerator-and-generator-in-the-segan-model-for-speech-enhan
# /users/1373669/kafman
# /questions/54823798/vue-apollo-cache-update-with-optimisticresponse-with-vuex
# /questions/tagged/vue.js
# /questions/tagged/vuex
# /questions/tagged/apollo
# /questions/tagged/apollo-client
# /questions/tagged/vue-apollo
# /questions/54823798/vue-apollo-cache-update-with-optimisticresponse-with-vuex
# /users/10704519/randomguy
# /questions/54823785/modules-in-project-interpreter-are-not-found-when-imported-pycharm
# /questions/tagged/python
# /questions/tagged/pycharm
# /questions/tagged/virtualenv
# /questions/tagged/python-import
# /questions/54823785/modules-in-project-interpreter-are-not-found-when-imported-pycharm
# /users/10878688/c-acarbay
# /questions/54823750/how-to-manage-rubygems-dependencies-in-serverless-framework
# /questions/tagged/serverless-framework
# /questions/tagged/serverless
# /questions/tagged/ruby-2.5
# /questions/54823750/how-to-manage-rubygems-dependencies-in-serverless-framework
# /users/4465049/chitra
# /questions/54820094/big-o-notation-and-time-complexity-of-c-code-snippet
# /questions/tagged/c%2b%2b
# /questions/54820094/big-o-notation-and-time-complexity-of-c-code-snippet
# /users/6594576/paul-floyd
# /questions/54823695/getting-the-date-from-google-ads
# /questions/tagged/google-data-studio
# /questions/54823695/getting-the-date-from-google-ads
# /users/8836991/sam-johnson
# /questions/54822702/rcpparmadillo-gamma-distribution-differs-between-platforms-with-same-seed
# /questions/tagged/r
# /questions/tagged/rcpp
# /questions/tagged/armadillo
# /questions/tagged/rcpp11
# /questions/54822702/rcpparmadillo-gamma-distribution-differs-between-platforms-with-same-seed
# /users/5397495/%c3%98ystein-s
# /questions/54801300/powerbi-visuals-tools-error-after-pbiviz-start-command
# /questions/tagged/powerbi
# /questions/tagged/powerbi-custom-visuals
# /questions/tagged/pbiviz
# /questions/54801300/powerbi-visuals-tools-error-after-pbiviz-start-command
# /users/4100253/marek
# /questions
# /tags
# /unanswered
# https://stackexchange.com/questions?tab=hot
# https://stats.stackexchange.com/questions/393316/do-error-bars-on-probabilities-have-any-meaning
# https://academia.stackexchange.com/questions/125149/found-a-major-flaw-in-paper-from-home-university-to-which-i-would-like-to-retu
# https://rpg.stackexchange.com/questions/141463/how-can-i-make-my-enemies-feel-real-and-make-combat-more-engaging
# https://money.stackexchange.com/questions/105604/how-does-holding-onto-an-active-but-un-used-credit-card-affect-your-ability-to-g
# https://pm.stackexchange.com/questions/25853/what-if-you-do-not-believe-in-the-project-benefits
# https://movies.stackexchange.com/questions/97264/in-the-lost-in-space-intro-why-was-dr-smith-actor-listed-as-a-special-guest-sta
# https://ell.stackexchange.com/questions/197771/question-are-you-hungry-answer-i-feel-like-eating
# https://salesforce.stackexchange.com/questions/251266/what-does-it-mean-when-an-external-id-field-follows-a-dml-statement
# https://serverfault.com/questions/955112/what-does-mean-in-a-hostname-in-dns-configuration
# https://writing.stackexchange.com/questions/42422/how-do-i-avoid-the-chosen-hero-feeling
# https://blender.stackexchange.com/questions/132550/reduce-reflections
# https://math.stackexchange.com/questions/3120653/why-do-we-divide-permutations-to-get-to-combinations
# https://english.stackexchange.com/questions/486582/can-i-do-anything-else-with-aspersions-other-than-cast-them
# https://superuser.com/questions/1408103/are-all-power-cords-made-equal
# https://electronics.stackexchange.com/questions/423629/why-are-square-law-devices-important
# https://travel.stackexchange.com/questions/132629/do-the-speed-limit-reductions-due-to-pollution-also-apply-to-electric-cars-in-fr
# https://worldbuilding.stackexchange.com/questions/139429/how-can-guns-be-countered-by-melee-combat-without-raw-ability-or-exceptional-exp
# https://workplace.stackexchange.com/questions/129365/manager-has-noticed-coworkers-excessive-breaks-should-i-warn-him
# https://worldbuilding.stackexchange.com/questions/139539/how-can-changes-in-personality-values-of-a-person-who-turned-into-a-vampire-be-e
# https://diy.stackexchange.com/questions/158243/why-do-single-electrical-receptacles-exist
# https://mathoverflow.net/questions/323779/what-is-an-explicit-bijection-in-combinatorics
# https://physics.stackexchange.com/questions/462089/why-do-we-interpret-the-accelerated-expansion-of-the-universe-as-the-proof-for-t
# https://tex.stackexchange.com/questions/476097/draw-triangle-with-text-in-vertices-edges
# https://codegolf.stackexchange.com/questions/180187/build-ascii-podiums
# /feeds
# https://stackoverflow.com
# https://stackoverflow.com
# /questions
# https://stackoverflow.com/jobs
# https://stackoverflow.com/jobs/directory/developer-jobs
# https://stackoverflow.com/jobs/salary
# /help
# None
# https://www.stackoverflowbusiness.com
# https://stackoverflow.com/teams
# https://www.stackoverflowbusiness.com/talent
# https://www.stackoverflowbusiness.com/advertise
# https://stackoverflow.com/enterprise
# https://stackoverflow.com/company/about
# https://stackoverflow.com/company/about
# https://stackoverflow.com/company/press
# https://stackoverflow.com/company/work-here
# https://stackoverflow.com/legal
# https://stackoverflow.com/legal/privacy-policy
# https://stackoverflow.com/company/contact
# https://stackexchange.com
# https://stackoverflow.com
# https://serverfault.com
# https://superuser.com
# https://webapps.stackexchange.com
# https://askubuntu.com
# https://webmasters.stackexchange.com
# https://gamedev.stackexchange.com
# https://tex.stackexchange.com
# https://softwareengineering.stackexchange.com
# https://unix.stackexchange.com
# https://apple.stackexchange.com
# https://wordpress.stackexchange.com
# https://gis.stackexchange.com
# https://electronics.stackexchange.com
# https://android.stackexchange.com
# https://security.stackexchange.com
# https://dba.stackexchange.com
# https://drupal.stackexchange.com
# https://sharepoint.stackexchange.com
# https://ux.stackexchange.com
# https://mathematica.stackexchange.com
# https://salesforce.stackexchange.com
# https://expressionengine.stackexchange.com
# https://pt.stackoverflow.com
# https://blender.stackexchange.com
# https://networkengineering.stackexchange.com
# https://crypto.stackexchange.com
# https://codereview.stackexchange.com
# https://magento.stackexchange.com
# https://softwarerecs.stackexchange.com
# https://dsp.stackexchange.com
# https://emacs.stackexchange.com
# https://raspberrypi.stackexchange.com
# https://ru.stackoverflow.com
# https://codegolf.stackexchange.com
# https://es.stackoverflow.com
# https://ethereum.stackexchange.com
# https://datascience.stackexchange.com
# https://arduino.stackexchange.com
# https://bitcoin.stackexchange.com
# https://stackexchange.com/sites#technology
# https://photo.stackexchange.com
# https://scifi.stackexchange.com
# https://graphicdesign.stackexchange.com
# https://movies.stackexchange.com
# https://music.stackexchange.com
# https://worldbuilding.stackexchange.com
# https://cooking.stackexchange.com
# https://diy.stackexchange.com
# https://money.stackexchange.com
# https://academia.stackexchange.com
# https://law.stackexchange.com
# https://stackexchange.com/sites#lifearts
# https://english.stackexchange.com
# https://skeptics.stackexchange.com
# https://judaism.stackexchange.com
# https://travel.stackexchange.com
# https://christianity.stackexchange.com
# https://ell.stackexchange.com
# https://japanese.stackexchange.com
# https://gaming.stackexchange.com
# https://bicycles.stackexchange.com
# https://rpg.stackexchange.com
# https://anime.stackexchange.com
# https://puzzling.stackexchange.com
# https://mechanics.stackexchange.com
# https://stackexchange.com/sites#culturerecreation
# https://mathoverflow.net
# https://math.stackexchange.com
# https://stats.stackexchange.com
# https://cstheory.stackexchange.com
# https://physics.stackexchange.com
# https://chemistry.stackexchange.com
# https://biology.stackexchange.com
# https://cs.stackexchange.com
# https://philosophy.stackexchange.com
# https://stackexchange.com/sites#science
# https://meta.stackexchange.com
# https://stackapps.com
# https://api.stackexchange.com
# https://data.stackexchange.com
# https://area51.stackexchange.com
# https://stackoverflow.blog?blb=1
# https://www.facebook.com/officialstackoverflow/
# https://twitter.com/stackoverflow
# https://linkedin.com/company/stack-overflow
# https://creativecommons.org/licenses/by-sa/3.0/
# https://stackoverflow.blog/2009/06/25/attribution-required/

# %%
body = soup.body
 # from body tag get all div tags with class 'related-links'
for div in body.find_all('div', class_ = "related-links"):
    print(div)
# Out:
# <div class="related-links">
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:14 })" href="https://stackoverflow.com/help">help</a>
# <a class="js-gps-track" data-gps-track="site_switcher.click({ item_type:6 })" href="https://chat.stackoverflow.com">chat</a>
# </div>

# %%
# get all src(url) of img
for img in body.find_all('img'):
    print(img.get('src'))
# Out:
# //i.stack.imgur.com/bk9VA.png
# //i.stack.imgur.com/bk9VA.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/gfrSH.png
# //i.stack.imgur.com/bk9VA.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/9J8MK.png
# //i.stack.imgur.com/bk9VA.png
# https://pixel.quantserve.com/pixel/p-c1rF4kxgLUzNc.gif

# %%
url2 = urlopen('https://www.w3schools.com/html/html_tables.asp').read()
soup2 = bs.BeautifulSoup(url2, 'lxml')
tbl = soup2.table
tbl
# Out:
# <table id="customers">
# <tr>
# <th>Company</th>
# <th>Contact</th>
# <th>Country</th>
# </tr>
# <tr>
# <td>Alfreds Futterkiste</td>
# <td>Maria Anders</td>
# <td>Germany</td>
# </tr>
# <tr>
# <td>Centro comercial Moctezuma</td>
# <td>Francisco Chang</td>
# <td>Mexico</td>
# </tr>
# <tr>
# <td>Ernst Handel</td>
# <td>Roland Mendel</td>
# <td>Austria</td>
# </tr>
# <tr>
# <td>Island Trading</td>
# <td>Helen Bennett</td>
# <td>UK</td>
# </tr>
# <tr>
# <td>Laughing Bacchus Winecellars</td>
# <td>Yoshi Tannamuri</td>
# <td>Canada</td>
# </tr>
# <tr>
# <td>Magazzini Alimentari Riuniti</td>
# <td>Giovanni Rovelli</td>
# <td>Italy</td>
# </tr>
# </table>

# %%
for td in tbl.find_all('td'):
    print(td.get_text())
# Out:
# Alfreds Futterkiste
# Maria Anders
# Germany
# Centro comercial Moctezuma
# Francisco Chang
# Mexico
# Ernst Handel
# Roland Mendel
# Austria
# Island Trading
# Helen Bennett
# UK
# Laughing Bacchus Winecellars
# Yoshi Tannamuri
# Canada
# Magazzini Alimentari Riuniti
# Giovanni Rovelli
# Italy

# %%
import pandas as pd

# %%
df = pd.read_html('https://www.w3schools.com/html/html_tables.asp', header = 0)
df
# Out:
# [                        Company           Contact  Country
#  0           Alfreds Futterkiste      Maria Anders  Germany
#  1    Centro comercial Moctezuma   Francisco Chang   Mexico
#  2                  Ernst Handel     Roland Mendel  Austria
#  3                Island Trading     Helen Bennett       UK
#  4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
#  5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy,
#            Tag                                        Description
#  0     <table>                                    Defines a table
#  1        <th>                   Defines a header cell in a table
#  2        <tr>                           Defines a row in a table
#  3        <td>                          Defines a cell in a table
#  4   <caption>                            Defines a table caption
#  5  <colgroup>  Specifies a group of one or more columns in a ...
#  6       <col>  Specifies column properties for each column wi...
#  7     <thead>               Groups the header content in a table
#  8     <tbody>                 Groups the body content in a table
#  9     <tfoot>               Groups the footer content in a table]

# %%
news_url = urlopen('https://www.aljazeera.net/news/science').read()
news = bs.BeautifulSoup(news_url, 'xml')
news.html
# Out:
# <html lang="ar">
# <input id="eId" type="hidden" value="9ff80bf7-97cf-47f2-8578-5a9df7842311"/>
# <input id="oId" type="hidden" value="25aebf6b-5b0b-4720-9a6d-edb5b5e83c67"/>
# <input id="QueryCookie" name="QueryCookie" runat="server" type="hidden" value="NewsStream25aebf6b-5b0b-4720-9a6d-edb5b5e83c67"/>
# <input id="sectionId" type="hidden" value="a46a2b7e-e23c-4964-b799-ab508f0481fa#"/>
# <input id="SubSections" type="hidden" value=""/>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="علوم" name="title"/>
# <meta content="اطلع على آخر الأخبار في عالم العلوم والتكنولوجيا. نظرة مفصلة على آخر الاختراعات العلمية والاتجاهات التقنية الحالية والمستقبلية." name="og:description"/>
# <meta content="اطلع على آخر الأخبار في عالم العلوم والتكنولوجيا. نظرة مفصلة على آخر الاختراعات العلمية والاتجاهات التقنية الحالية والمستقبلية." name="twitter:description"/>
# <meta content="اطلع على آخر الأخبار في عالم العلوم والتكنولوجيا. نظرة مفصلة على آخر الاختراعات العلمية والاتجاهات التقنية الحالية والمستقبلية." name="description"/>
# <meta content="https://aljazeera.net/" property="og:url"/>
# <meta content="علوم" property="og:title"/>
# <meta content="https://www.aljazeera.net/Views/Shared/shared/images/VoteShare.jpg" itemprop="image" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="https://aljazeera.net/" name="twitter:url"/>
# <meta content="علوم" name="twitter:title"/>
# <meta content="https://aljazeera.net/Content/images/headerlogo.png" name="twitter:image:src"/>
# <meta content="علوم" name="twitter:image:alt"/>
# <script type="text/javascript">
#     window.privLanguage = "AR";
#     window.privDisableCSSInjection = "true";
# </script>
# <!-- GDPR script -->
# <link href="/content/css/ensArabic.css" rel="stylesheet" type="text/css"/>
# <script src="//tags.aljazeera.net/aljazeera/arabic/Bootstrap.js" type="text/javascript"/>
# <!-- Facebook Pixel Code -->
# <script>
#     !function (f, b, e, v, n, t, s) {
#         if (f.f‌bq) return; n = f.f‌bq = function () {
#             n.callMethod ? n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#         };
#         if (!f._f‌bq) f._f‌bq = n; n.push = n; n.loaded = !0; n.version = '2.0';
#         n.queue = []; t = b.createElement(e); t.async = !0;
#         t.src = v; s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s)
#     }(window, document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#     f‌bq('init', '309628272978573');
#     f‌bq('track', 'PageView');
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=309628272978573=PageView=1" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <script src="/Content/js/prebid.js" type="text/javascript"/>
# <script language="javascript" type="text/javascript">
#
#         /* Prebid Config Section START , Make sure this is inserted before your GPT tag */
#         try {
#             if (privOptOutAdvertising == undefined || privOptOutAdvertising == null || typeof privOptOutAdvertising !== boolean) {
#                 privOptOutAdvertising = false; // a false value here will enable targeted ads
#             }
#         }
#         catch (err) {
#
#             var privOptOutAdvertising = false;
#
#         }
#
#         var dT = 2000, // desktop timeout
#         mT = 3000; // mobile timeout
#         var PREBID_TIMEOUT = /webOS|Mobile|iP(hone|od)|iPad|Android|BlackBerry|IEMobile|Silk/.test(navigator.userAgent) ? mT : dT;
#
#         var isMobile = function () {
#             return window.navigator.userAgent.indexOf('Mobile') &gt; -1;
#         };
#
#
#         var adUnits = [{
#             code: 'div-gpt-ad-1395743456679-4',     //leaderboeard
#             sizes: isMobile() ? [[468, 60], [320, 50], [300, 50]] : [[728, 90], [970, 90]],
#             bids: [{
#                 bidder: 'rubicon',
#                 params: {
#                     accountId: '14882',
#                     siteId: isMobile() ? '86950' : '84950',
#                     zoneId: isMobile() ? '411082' : '410126',
#
#                 }
#             }, {
#                 bidder: 'criteo',
#                 params: { zoneId: isMobile() ? '853210' : '1105350' }
#             }]
#         }, {
#             code: 'div-gpt-ad-1395743456679-8',     //leaderboeard
#             sizes: isMobile() ? [[468, 60], [320, 50], [300, 50]] : [[728, 90]],
#             bids: [{
#                 bidder: 'rubicon',
#                 params: {
#                     accountId: '14882',
#                     siteId: isMobile() ? '86950' : '84950',
#                     zoneId: isMobile() ? '411082' : '410126',
#
#                 }
#             }, {
#                 bidder: 'criteo',
#                 params: { zoneId: isMobile() ? '853210' : '1105350' }
#             }
#             ]
#         }, {
#             code: 'div-gpt-ad-1395743456679-0',     //300x250
#             sizes: isMobile() ? [[300, 250], [250, 250]] : [[300, 250], [250, 250]],
#             bids: [{
#                 bidder: 'rubicon',
#                 params: {
#                     accountId: '14882',
#                     siteId: isMobile() ? '86950' : '84950',
#                     zoneId: isMobile() ? '411082' : '410126',
#
#                 }
#             }, {
#                 bidder: 'criteo',
#                 params: { zoneId: isMobile() ? '780491' : '780491' }
#             }
#             ]
#
#         }];
#
#         var pbjs = pbjs || {};
#         pbjs.que = pbjs.que || [];
#         pbjs.que.push(function () {
#             pbjs.setConfig({
#                 consentManagement: {
#                     cmpApi: 'iab',
#                     timeout: 8000,
#                     allowAuctionWithoutConsent: privOptOutAdvertising // </script></head></html>

# %%
news.html.find_all('script') # get all JS codes
# Out:
# [<script type="text/javascript">
#      window.privLanguage = "AR";
#      window.privDisableCSSInjection = "true";
#  </script>,
#  <script src="//tags.aljazeera.net/aljazeera/arabic/Bootstrap.js" type="text/javascript"/>,
#  <script>
#      !function (f, b, e, v, n, t, s) {
#          if (f.f‌bq) return; n = f.f‌bq = function () {
#              n.callMethod ? n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#          };
#          if (!f._f‌bq) f._f‌bq = n; n.push = n; n.loaded = !0; n.version = '2.0';
#          n.queue = []; t = b.createElement(e); t.async = !0;
#          t.src = v; s = b.getElementsByTagName(e)[0];
#          s.parentNode.insertBefore(t, s)
#      }(window, document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#      f‌bq('init', '309628272978573');
#      f‌bq('track', 'PageView');
#  </script>,
#  <script src="/Content/js/prebid.js" type="text/javascript"/>,
#  <script language="javascript" type="text/javascript">
#
#          /* Prebid Config Section START , Make sure this is inserted before your GPT tag */
#          try {
#              if (privOptOutAdvertising == undefined || privOptOutAdvertising == null || typeof privOptOutAdvertising !== boolean) {
#                  privOptOutAdvertising = false; // a false value here will enable targeted ads
#              }
#          }
#          catch (err) {
#
#              var privOptOutAdvertising = false;
#
#          }
#
#          var dT = 2000, // desktop timeout
#          mT = 3000; // mobile timeout
#          var PREBID_TIMEOUT = /webOS|Mobile|iP(hone|od)|iPad|Android|BlackBerry|IEMobile|Silk/.test(navigator.userAgent) ? mT : dT;
#
#          var isMobile = function () {
#              return window.navigator.userAgent.indexOf('Mobile') &gt; -1;
#          };
#
#
#          var adUnits = [{
#              code: 'div-gpt-ad-1395743456679-4',     //leaderboeard
#              sizes: isMobile() ? [[468, 60], [320, 50], [300, 50]] : [[728, 90], [970, 90]],
#              bids: [{
#                  bidder: 'rubicon',
#                  params: {
#                      accountId: '14882',
#                      siteId: isMobile() ? '86950' : '84950',
#                      zoneId: isMobile() ? '411082' : '410126',
#
#                  }
#              }, {
#                  bidder: 'criteo',
#                  params: { zoneId: isMobile() ? '853210' : '1105350' }
#              }]
#          }, {
#              code: 'div-gpt-ad-1395743456679-8',     //leaderboeard
#              sizes: isMobile() ? [[468, 60], [320, 50], [300, 50]] : [[728, 90]],
#              bids: [{
#                  bidder: 'rubicon',
#                  params: {
#                      accountId: '14882',
#                      siteId: isMobile() ? '86950' : '84950',
#                      zoneId: isMobile() ? '411082' : '410126',
#
#                  }
#              }, {
#                  bidder: 'criteo',
#                  params: { zoneId: isMobile() ? '853210' : '1105350' }
#              }
#              ]
#          }, {
#              code: 'div-gpt-ad-1395743456679-0',     //300x250
#              sizes: isMobile() ? [[300, 250], [250, 250]] : [[300, 250], [250, 250]],
#              bids: [{
#                  bidder: 'rubicon',
#                  params: {
#                      accountId: '14882',
#                      siteId: isMobile() ? '86950' : '84950',
#                      zoneId: isMobile() ? '411082' : '410126',
#
#                  }
#              }, {
#                  bidder: 'criteo',
#                  params: { zoneId: isMobile() ? '780491' : '780491' }
#              }
#              ]
#
#          }];
#
#          var pbjs = pbjs || {};
#          pbjs.que = pbjs.que || [];
#          pbjs.que.push(function () {
#              pbjs.setConfig({
#                  consentManagement: {
#                      cmpApi: 'iab',
#                      timeout: 8000,
#                      allowAuctionWithoutConsent: privOptOutAdvertising // </script>]
